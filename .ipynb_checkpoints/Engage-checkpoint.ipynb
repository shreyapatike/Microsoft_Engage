# %%
import pandas as pd

# %%
df = pd.read_csv("dataset.csv")
#pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Shreya\Desktop\Engage project\.ipynb_checkpoints\Engage-checkpoint.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Shreya/Desktop/Engage%20project/.ipynb_checkpoints/Engage-checkpoint.ipynb#ch0000001?line=0'>1</a> df = pd.read_csv("dataset.csv")
#
# File c:\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
# ...

# %%
df.shape
# Out:
# (1276, 141)

# %%
df.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 0                In-line  ...                      NaN                 NaN
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0    Cylinders  Valves_Per_Cylinder        Doors  \
# count  1276.000000  1210.000000          1174.000000  1272.000000
# mean    637.500000     4.380992             3.977853     4.550314
# std     368.493781     1.660957             0.833763     0.747816
# min       0.000000     2.000000             1.000000     2.000000
# 25%     318.750000     4.000000             4.000000     4.000000
# 50%     637.500000     4.000000             4.000000     5.000000
# 75%     956.250000     4.000000             4.000000     5.000000
# max    1275.000000    16.000000            16.000000     5.000000
#
#        Seating_Capacity  Number_of_Airbags  USB_Ports
# count       1270.000000        1141.000000  29.000000
# mean           5.270079           3.787029   1.793103
# std            1.145231           2.522399   0.773642
# min            2.000000           1.000000   1.000000
# 25%            5.000000           2.000000   1.000000
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Make', 'Model', 'Variant', 'Ex-Showroom_Price',
#        'Displacement', 'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=141)

# %%
df.nunique()
# Out:
# Unnamed: 0           1276
# Make                   39
# Model                 263
# Variant              1064
# Ex-Showroom_Price    1179
#                      ...
# USB_Ports               3
# Heads-Up_Display        1
# Welcome_Lights          1
# Battery                 5
# Electric_Range          8
# Length: 141, dtype: int64

# %% [markdown]
# ## Feature Ananlysis

# %%
df.isnull().sum(axis = 0)
# Out:
# Unnamed: 0              0
# Make                   75
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
#                      ...
# USB_Ports            1247
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 141, dtype: int64

# %%
del_cols =['Electric_Range','Battery','Welcome_Lights','Heads-Up_Display',
          'USB_Ports','Cruise_Control','ASR_/_Traction_Control','Engine_Type',
          'Automatic_Headlamps','Leather_Wrapped_Steering','Paddle_Shifters',
          'Rain_Sensing_Wipers','ISOFIX_(Child-Seat_Mount)','Heated_Seats',
          'Recommended_Tyre_Pressure','Cooled_Glove_Box','ESP_(Electronic_Stability_Program)',
          'iPod_Compatibility','Tyre_Pressure_Monitoring_System','Apple_CarPlay',
          'Android_Auto','Other_specs','Other_Specs','Compression_Ratio',
           'Walk_Away_Auto_Car_Lock','Voice_Recognition','Passenger_Side_Seat-Belt_Reminder',
          'Lane_Watch_Camera/_Side_Mirror_Camera','High_Speed_Alert_System',
          'Drive_Modes','Cargo/Boot_Lights','Ambient_Lightning'
           ,'3_Point_Seat-Belt_in_Middle_Rear_Seat'
          ,'Hill_Assist','Extended_Warranty','Start_/_Stop_Button','Power_Seats','Rear_Track',
          'Front_Track','ARAI_Certified_Mileage_for_CNG','Highway_Mileage']

# %%
df.drop(del_cols, axis=1, inplace=True) # Lots of nulls #

# %%
df.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Cigarette_Lighter Infotainment_Screen  \
# 0                In-line  ...               NaN                 NaN
# ...

# %%
this = df['Make']
print(this.value_counts())
print(this.value_counts().shape)
print(this.isna().sum())
# Out:
# Maruti Suzuki       149
# Hyundai             130
# Mahindra            119
# Tata                100
# Toyota               82
# Honda                64
# Skoda                43
# Ford                 43
# Bmw                  37
# Renault              36
# Volkswagen           34
# Audi                 31
# Nissan               29
# Jeep                 28
# Land Rover Rover     27
# Fiat                 23
# Jaguar               22
# Kia                  21
# Volvo                18
# Datsun               15
# Porsche              14
# Maruti Suzuki R      14
# Lamborghini          13
# Mg                   13
# Icml                 11
# Land Rover           10
# Lexus                10
# Mini                 10
# Maserati              9
# Ferrari               8
# Mitsubishi            7
# Bentley               6
# Premier               6
# Force                 6
# Isuzu                 5
# Aston Martin          3
# Bajaj                 2
# Bugatti               2
# ...

# %%
# Manually checked the null "Make" rows #
df['Make']=df['Make'].fillna(value='Benz')
df.loc[df['Model']=='Rolls-Royce Ghost Series Ii','Make']='RollsRoys'
df.loc[df['Model']=='Rolls-Royce Wraith','Make']='RollsRoys'
df.loc[df['Model']=='Rolls-Royce Cullinan','Make']='RollsRoys'
df.loc[df['Model']=='Rolls-Royce Phantom Coupe','Make']='RollsRoys'
df.loc[df['Model']=='Rolls-Royce Dawn','Make']='RollsRoys'
df.loc[df['Model']=='Rolls-Royce Phantom','Make']='RollsRoys'
df.loc[df['Model']=='Rolls-Royce Drophead Coupe','Make']='RollsRoys'
df.loc[df['Model']=='Go+','Make']='Datsun'

# %%
this = df['Make']
print(this.value_counts())
print(this.value_counts().shape)
print(this.isna().sum())
# Out:
# Maruti Suzuki       149
# Hyundai             130
# Mahindra            119
# Tata                100
# Toyota               82
# Honda                64
# Benz                 57
# Ford                 43
# Skoda                43
# Bmw                  37
# Renault              36
# Volkswagen           34
# Audi                 31
# Nissan               29
# Jeep                 28
# Land Rover Rover     27
# Datsun               24
# Fiat                 23
# Jaguar               22
# Kia                  21
# Volvo                18
# Maruti Suzuki R      14
# Porsche              14
# Lamborghini          13
# Mg                   13
# Icml                 11
# Mini                 10
# Lexus                10
# Land Rover           10
# Maserati              9
# RollsRoys             9
# Ferrari               8
# Mitsubishi            7
# Bentley               6
# Force                 6
# Premier               6
# Isuzu                 5
# Aston Martin          3
# ...

# %%
this = df['Variant']
print(this.value_counts())
print(this.value_counts().shape)
print(this.isna().sum())
df.drop(['Variant'],axis=1, inplace=True) # Lot of categories #
# Out:
# Lxi                         9
# Vxi                         9
# Coupe                       8
# S                           7
# V8                          6
#                            ..
# 1.4 Crdi Mt Sx Dual Tone    1
# 1.4 Crdi Mt Sx(O)           1
# Xz                          1
# Xz Plus Dual Tone           1
# 3.2 At                      1
# Name: Variant, Length: 1064, dtype: int64
# (1064,)
# 0

# %%
df.shape
# Out:
# (1276, 99)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Make', 'Model', 'Ex-Showroom_Price', 'Displacement',
#        'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration', 'Emission_Norm', 'Engine_Location',
#        'Fuel_System', 'Fuel_Tank_Capacity', 'Fuel_Type', 'Height', 'Length',
#        'Width', 'Body_Type', 'Doors', 'City_Mileage', 'ARAI_Certified_Mileage',
#        'Kerb_Weight', 'Gears', 'Ground_Clearance', 'Front_Brakes',
#        'Rear_Brakes', 'Front_Suspension', 'Rear_Suspension',
#        'Front_Tyre_&_Rim', 'Rear_Tyre_&_Rim', 'Power_Steering',
#        'Power_Windows', 'Keyless_Entry', 'Power', 'Torque', 'Odometer',
#        'Speedometer', 'Tachometer', 'Tripmeter', 'Seating_Capacity',
#        'Seats_Material', 'Type', 'Wheelbase', 'Wheels_Size',
#        '12v_Power_Outlet', 'Audiosystem', 'Aux-in_Compatibility',
#        'Average_Fuel_Consumption', 'Basic_Warranty', 'Bluetooth',
#        'Boot-lid_Opener', 'Boot_Space', 'CD_/_MP3_/_DVD_Player',
# ...

# %%
categorical = ['Make','Model','Drivetrain','Cylinder_Configuration',
              'Emission_Norm','Engine_Location','Fuel_System','Fuel_Type','Body_Type',
              'Gears','Front_Brakes','Rear_Brakes','Power_Steering','Power_Windows',
              'Keyless_Entry','Odometer','Speedometer','Tachometer','Tripmeter',
              'Seats_Material','Type','12v_Power_Outlet','Audiosystem','Basic_Warranty',
              'Boot-lid_Opener','Clock','Cup_Holders','Door_Pockets','Fuel-lid_Opener',
              'Fuel_Gauge','Handbrake','Instrument_Console','Sun_Visor','Third_Row_AC_Vents',
              'Ventilation_System','Adjustable_Headrests','Adjustable_Steering_Column',
              'Parking_Assistance','Infotainment_Screen','Multifunction_Steering_Wheel',
              'Seat_Height_Adjustment','Rear_Center_Armrest']

numerical = ['Cylinders','Valves_Per_Cylinder','Doors','Seating_Capacity','Number_of_Airbags']

str_num = ['Ex-Showroom_Price','Displacement','Fuel_Tank_Capacity','Height','Length','Width',
           'ARAI_Certified_Mileage','Kerb_Weight','Ground_Clearance',
          'City_Mileage','Boot_Space','Minimum_Turning_Radius'#,'Gross_Vehicle_Weight'
          ]
nulls_are_no = ['Cigarette_Lighter','EBA_(Electronic_Brake_Assist)',
               'Navigation_System','Second_Row_AC_Vents',
               'Turbocharger']

cat_more = ['Front_Suspension','Rear_Suspension','Front_Tyre_&_Rim',
            'Rear_Tyre_&_Rim','Power','Torque','Wheelbase','Wheels_Size',
           'Airbags']

# %%
new_df = pd.DataFrame()

# %%
for feature in numerical:
    new_df[feature]=df[feature]
    new_df[feature].fillna(new_df[feature].mean(), inplace=True)
for num_feature in str_num:
    new_df[num_feature] = df[num_feature]
    new_df[num_feature].fillna(new_df[num_feature].mode()[0], inplace=True) 
    new_df[num_feature] = new_df[num_feature].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
for cat_feature in categorical:
    new_df[cat_feature]=df[cat_feature]
    new_df[cat_feature].fillna(new_df[cat_feature].mode()[0],inplace=True)
for feature in nulls_are_no:
    new_df[feature]=df[feature]
    new_df[feature]=new_df[feature].fillna(value='No')
    
'''for feature in cat_more:
    new_df[feature]=df[feature]
    new_df[feature].fillna(new_df[feature].mode()[0],inplace=True)'''
# Out:
# 'for feature in cat_more:\n    new_df[feature]=df[feature]\n    new_df[feature].fillna(new_df[feature].mode()[0],inplace=True)'

# %%
new_df.head()
# Out:
#    Cylinders  Valves_Per_Cylinder  Doors  Seating_Capacity  Number_of_Airbags  \
# 0        2.0                  2.0    5.0               4.0           3.787029
# 1        2.0                  2.0    5.0               4.0           3.787029
# 2        2.0                  2.0    4.0               4.0           3.787029
# 3        2.0                  2.0    5.0               4.0           3.787029
# 4        2.0                  2.0    5.0               4.0           3.787029
#
#    Ex-Showroom_Price  Displacement  Fuel_Tank_Capacity  Height  Length  ...  \
# 0             292667           624                  24    1652    3164  ...
# 1             236447           624                  24    1652    3164  ...
# 2             296661           624                  15    1652    3164  ...
# 3             334768           624                  24    1652    3164  ...
# 4             272223           624                  24    1652    3164  ...
#
# ...

# %%
#new_df.describe

# %%
for feature in categorical:
    new_df[feature]=new_df[feature].astype('category').cat.codes
for feature in nulls_are_no:
    new_df[feature]=new_df[feature].astype('category').cat.codes
#for feature in cat_more:
#    new_df[feature]=new_df[feature].astype('category').cat.codes

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numerical_df = pd.DataFrame()
for feature in numerical:
    numerical_df[feature]=new_df[feature]
corelation = numerical_df.corr()
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,
           annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(numerical_df)

# %%
sns.distplot(numerical_df['Cylinders'])
# Out:
# /home/datta/python/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Cylinders', ylabel='Density'>

# %%
sns.catplot(x='Number_of_Airbags',kind='box',data=numerical_df)

# %%
str_num_df = pd.DataFrame()
for feature in str_num:
    str_num_df[feature]=new_df[feature]
corelation = str_num_df.corr()
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,
           annot=True)
sns.despine()

# %%
sns.pairplot(str_num_df)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 sns.pairplot(str_num_df)
#
# File ~/python/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/python/lib/python3.8/site-packages/seaborn/axisgrid.py:2126, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2124 diag_kws.setdefault("legend", False)
# ...

# %%
'''categorical_df = pd.DataFrame()
for cat_feature in categorical:
    categorical_df[cat_feature]=new_df[cat_feature]
corelation = categorical_df.corr()
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,
           annot=True)
sns.despine()'''
# Out:
# 'categorical_df = pd.DataFrame()\nfor cat_feature in categorical:\n    categorical_df[cat_feature]=new_df[cat_feature]\ncorelation = categorical_df.corr()\nfig, ax = plt.subplots()\nfig.set_size_inches(11.7, 8.27)\nsns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,\n           annot=True)\nsns.despine()'

# %%
#sns.pairplot(new_df)

# %%
#sns.relplot(x)

# %%
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.utils import shuffle
new_df = shuffle(new_df)

# %%
#new_df.isnull().sum()

# %%
features = ['Make','Drivetrain','Cylinder_Configuration',
              'Emission_Norm','Engine_Location','Fuel_System','Fuel_Type','Body_Type',
              'Gears','Front_Brakes','Rear_Brakes','Power_Steering','Power_Windows',
              'Keyless_Entry','Odometer','Speedometer','Tachometer','Tripmeter',
              'Seats_Material','Type','12v_Power_Outlet','Audiosystem','Basic_Warranty',
              'Boot-lid_Opener','Clock','Cup_Holders','Door_Pockets','Fuel-lid_Opener',
              'Fuel_Gauge','Handbrake','Instrument_Console','Sun_Visor','Third_Row_AC_Vents',
              'Ventilation_System','Adjustable_Headrests','Adjustable_Steering_Column',
              'Parking_Assistance','Infotainment_Screen','Multifunction_Steering_Wheel',
              'Seat_Height_Adjustment','Rear_Center_Armrest','Cylinders','Valves_Per_Cylinder',
            'Length','Width','Doors','City_Mileage','ARAI_Certified_Mileage','Kerb_Weight',
            'Ground_Clearance','Seating_Capacity','Number_of_Airbags','Ex-Showroom_Price',
            'Displacement','Fuel_Tank_Capacity','Height','Boot_Space','Minimum_Turning_Radius',
            #'Gross_Vehicle_Weight',
            #'Cigarette_Lighter','EBA_(Electronic_Brake_Assist)',
             #  'Navigation_System','Second_Row_AC_Vents','Turbocharger',
            #cat_more#
           # 'Front_Suspension','Rear_Suspension','Front_Tyre_&_Rim',
            #'Rear_Tyre_&_Rim','Power','Torque','Wheelbase','Wheels_Size',
           #'Airbags'
           ]
target = ['Model']
x = new_df[features]
y = new_df[target]

x_tr, x_test, y_tr, y_test = train_test_split(x, y, test_size=0.2)
x_train, x_validation, y_train, y_validation = train_test_split(x_tr, y_tr, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(x_train, y_train)
print(regr.score(x_validation, y_validation))
# Out:
# 0.1358076400946342
